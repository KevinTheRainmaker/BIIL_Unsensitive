# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('ggplot')

mpl.rcParams['axes.unicode_minus'] = False

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # DILI

# %% [markdown]
# ## Logistic Regression

# %%
#Basic
df = pd.read_csv('./Metrics/DILI_lr_basic.csv',index_col=0)
df.sample()
# Out:
#     0         1         2         3         4         5
# 5  32  0.586253  0.581192  0.569545  0.561075  0.569545

# %%
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_lr_basic.jpg')

# %%
#Normalize
df = pd.read_csv('./Metrics/DILI_lr_minmax.csv',index_col=0)
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_lr_minmax.jpg')

# %%
#Over
df = pd.read_csv('./Metrics/DILI_lr_over.csv',index_col=0)
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_lr_over.jpg')

# %%
#Over-only
df = pd.read_csv('./Metrics/DILI_lr_over_only.csv',index_col=0)
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_lr_over_only.jpg')

# %% [markdown]
# ## LGBM

# %%
#Basic
df = pd.read_csv('./Metrics/DILI_lgbm_basic.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
df.sample()
# Out:
#            0          1         2         3        4         5        6  \
# 13  lr: 0.05  tree: 400  0.712028  0.711116  0.70662  0.707452  0.70662
#
#                   param
# 13  lr: 0.05\ntree: 400

# %%
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)

plt.savefig('./Metrics/figure/DILI_lgbm_basic.jpg')

# %%
#Norm
df = pd.read_csv('./Metrics/DILI_lgbm_minmax.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)

x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)

plt.savefig('./Metrics/figure/DILI_lgbm_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/DILI_lgbm_over.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)

x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)

plt.savefig('./Metrics/figure/DILI_lgbm_over.jpg')

# %%
#over-only
df = pd.read_csv('./Metrics/DILI_lgbm_over_only.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)

x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)

plt.savefig('./Metrics/figure/DILI_lgbm_over_only.jpg')

# %% [markdown]
# ## RandomForest

# %%
#Basic
df = pd.read_csv('./Metrics/DILI_rf_basic.csv',index_col=0)
df.sample()
# Out:
#      0         1         2         3         4         5
# 3  400  0.716975  0.728828  0.712119  0.712934  0.713273

# %%
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_rf_basic.jpg')

# %%
#Normalize
df = pd.read_csv('./Metrics/DILI_rf_minmax.csv',index_col=0)

x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_rf_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/DILI_rf_over.csv',index_col=0)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_rf_over.jpg')

# %%
#over-only
df = pd.read_csv('./Metrics/DILI_rf_over_only.csv',index_col=0)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_rf_over_only.jpg')

# %% [markdown]
# ## k-NN

# %%
#Basic
df = pd.read_csv('./Metrics/DILI_knn_basic.csv',index_col=0)
df.sample()
# Out:
#    0         1         2         3         4         5
# 2  7  0.619489  0.615754  0.610983  0.610578  0.610983

# %%
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_knn_basic.jpg')

# %%
#Norm
df = pd.read_csv('./Metrics/DILI_knn_minmax.csv',index_col=0)
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_knn_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/DILI_knn_over.csv',index_col=0)
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_knn_over.jpg')

# %%
#over-only
df = pd.read_csv('./Metrics/DILI_knn_over_only.csv',index_col=0)
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_knn_over_only.jpg')

# %% [markdown]
# ## SVM

# %%
#Basic
df = pd.read_csv('./Metrics/DILI_svm_basic.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'C: ' + df['0']
df['1'] = 'gamma: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
df.sample()
# Out:
#         0              1         2         3         4         5         6  \
# 8  C: 100  gamma: 0.0001  0.670252  0.667963  0.666643  0.666735  0.666643
#
#                    param
# 8  C: 100\ngamma: 0.0001

# %%
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.tight_layout()
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=30, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.1, right=0.98, bottom=0.25, top=0.95)
plt.savefig('./Metrics/figure/DILI_svm_basic.jpg')

# %%
#Norm
df = pd.read_csv('./Metrics/DILI_svm_minmax.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'C: ' + df['0']
df['1'] = 'gamma: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=30, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.1, right=0.98, bottom=0.25, top=0.95)

plt.savefig('./Metrics/figure/DILI_svm_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/DILI_svm_over.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'C: ' + df['0']
df['1'] = 'gamma: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

# plt.figure(figsize=(6,4))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=30, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.12, right=0.98, bottom=0.25, top=0.95)

plt.savefig('./Metrics/figure/DILI_svm_over.jpg')

# %%
#over-only
df = pd.read_csv('./Metrics/DILI_svm_over_only.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'C: ' + df['0']
df['1'] = 'gamma: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=30, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.12, right=0.98, bottom=0.25, top=0.95)

plt.savefig('./Metrics/figure/DILI_svm_over_only.jpg')

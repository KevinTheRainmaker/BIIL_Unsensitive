# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('ggplot')

mpl.rcParams['axes.unicode_minus'] = False

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # DILI

# %% [markdown]
# ## Logistic Regression

# %%
#Basic
df = pd.read_csv('./Metrics/DILI_lr_basic.csv',index_col=0)
df.sample()
# Out:
#     0         1         2         3         4         5
# 4  16  0.604675  0.601591  0.590181  0.584803  0.590181

# %%
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=2)
plt.savefig('./Metrics/figure/DILI_lr_basic.jpg')

# %%
#Normalize
df = pd.read_csv('./Metrics/DILI_lr_minmax.csv',index_col=0)
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_lr_minmax.jpg')

# %%
#Over
df = pd.read_csv('./Metrics/DILI_lr_over.csv',index_col=0)
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_lr_over.jpg')

# %% [markdown]
# ## LGBM

# %%
#Basic
df = pd.read_csv('./Metrics/DILI_lgbm_basic.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
df.sample()
# Out:
#            0          1        2         3         4         5         6  \
# 24  lr: 0.01  tree: 500  0.71248  0.712181  0.705688  0.706658  0.705688
#
#                   param
# 24  lr: 0.01\ntree: 500

# %%
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


plt.savefig('./Metrics/figure/DILI_lgbm_basic.jpg')

# %%
#Norm
df = pd.read_csv('./Metrics/DILI_lgbm_minmax.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)

x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


plt.savefig('./Metrics/figure/DILI_lgbm_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/DILI_lgbm_over.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)

x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


plt.savefig('./Metrics/figure/DILI_lgbm_over.jpg')

# %% [markdown]
# ## RandomForest

# %%
#Basic
df = pd.read_csv('./Metrics/DILI_rf_basic.csv',index_col=0)
df.sample()
# Out:
#      0         1         2         3         4         5
# 1  200  0.721017  0.724379  0.707996  0.712947  0.717476

# %%
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.savefig('./Metrics/figure/DILI_rf_basic.jpg')

# %%
#Normalize
df = pd.read_csv('./Metrics/DILI_rf_minmax.csv',index_col=0)

x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.savefig('./Metrics/figure/DILI_rf_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/DILI_rf_over.csv',index_col=0)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.savefig('./Metrics/figure/DILI_rf_over.jpg')

# %% [markdown]
# ## k-NN

# %%
#Basic
df = pd.read_csv('./Metrics/DILI_knn_basic.csv',index_col=0)
df.sample()
# Out:
#    0         1         2         3         4         5
# 2  7  0.619489  0.615754  0.610983  0.610578  0.610983

# %%
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_knn_basic.jpg')

# %%
#Norm
df = pd.read_csv('./Metrics/DILI_knn_minmax.csv',index_col=0)
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_knn_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/DILI_knn_over.csv',index_col=0)
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/DILI_knn_over.jpg')

# %% [markdown]
# ## SVM

# %%
#Basic
df = pd.read_csv('./Metrics/DILI_svm_basic.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'C: ' + df['0']
df['1'] = 'gamma: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
df.sample()
# Out:
#       0            1         2         3         4         5         6  \
# 0  C: 1  gamma: 0.01  0.623088  0.685429  0.592231  0.551028  0.592231
#
#                param
# 0  C: 1\ngamma: 0.01

# %%
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.tight_layout()
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=30, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.1, right=0.98, bottom=0.25, top=0.95)
plt.savefig('./Metrics/figure/DILI_svm_basic.jpg')

# %%
#Norm
df = pd.read_csv('./Metrics/DILI_svm_minmax.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'C: ' + df['0']
df['1'] = 'gamma: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=30, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.1, right=0.98, bottom=0.25, top=0.95)

plt.savefig('./Metrics/figure/DILI_svm_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/DILI_svm_over.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'C: ' + df['0']
df['1'] = 'gamma: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

# plt.figure(figsize=(6,4))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=30, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.12, right=0.98, bottom=0.25, top=0.95)

plt.savefig('./Metrics/figure/DILI_svm_over.jpg')

# %% [markdown]
# # AMES

# %% [markdown]
# ## lr

# %%
#Basic
df = pd.read_csv('./Metrics/AMES_lr_basic.csv',index_col=0)
df.sample()
# Out:
#     0         1         2         3         4         5
# 5  32  0.767169  0.764082  0.762445  0.763055  0.762445

# %%
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=2)
plt.savefig('./Metrics/figure/AMES_lr_basic.jpg')

# %%
#Normalize
df = pd.read_csv('./Metrics/AMES_lr_minmax.csv',index_col=0)
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/AMES_lr_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/AMES_lr_over.csv',index_col=0)
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/AMES_lr_over.jpg')

# %% [markdown]
# ## lgbm

# %%
#Basic
df = pd.read_csv('./Metrics/AMES_lgbm_basic.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
df.sample()
# Out:
#          0          1         2         3         4        5         6  \
# 2  lr: 0.1  tree: 300  0.830626  0.828569  0.827357  0.82785  0.827357
#
#                 param
# 2  lr: 0.1\ntree: 300

# %%
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


plt.savefig('./Metrics/figure/AMES_lgbm_basic.jpg')

# %%
#Norm
df = pd.read_csv('./Metrics/AMES_lgbm_minmax.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)

x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


plt.savefig('./Metrics/figure/AMES_lgbm_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/AMES_lgbm_over.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)

x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


plt.savefig('./Metrics/figure/AMES_lgbm_over.jpg')

# %% [markdown]
# ## RF

# %%
#Basic
df = pd.read_csv('./Metrics/AMES_rf_basic.csv',index_col=0)
df.sample()
# Out:
#      0         1         2        3         4         5
# 5  600  0.834455  0.834004  0.83375  0.831958  0.833044

# %%
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.savefig('./Metrics/figure/AMES_rf_basic.jpg')

# %%
#Normalize
df = pd.read_csv('./Metrics/AMES_rf_minmax.csv',index_col=0)

x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.savefig('./Metrics/figure/AMES_rf_minmax.jpg')

# %%
#Normalize
df = pd.read_csv('./Metrics/AMES_rf_over.csv',index_col=0)

x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.savefig('./Metrics/figure/AMES_rf_over.jpg')

# %% [markdown]
# ## k-NN

# %%
#Basic
df = pd.read_csv('./Metrics/AMES_knn_basic.csv',index_col=0)
df.sample()
# Out:
#    0         1         2         3         4         5
# 0  3  0.720998  0.716996  0.714746  0.715574  0.714746

# %%
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=1)
plt.savefig('./Metrics/figure/AMES_knn_basic.jpg')

# %%
df = pd.read_csv('./Metrics/AMES_knn_minmax.csv',index_col=0)
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=3)
plt.savefig('./Metrics/figure/AMES_knn_minmax.jpg')

# %%
df = pd.read_csv('./Metrics/AMES_knn_over.csv',index_col=0)
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=3)
plt.savefig('./Metrics/figure/AMES_knn_over.jpg')

# %% [markdown]
# ## SVM

# %%
#Basic
df = pd.read_csv('./Metrics/AMES_svm_basic.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'C: ' + df['0']
df['1'] = 'gamma: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
df.sample()
# Out:
#       0              1         2         3         4         5         6  \
# 2  C: 1  gamma: 0.0001  0.639907  0.680963  0.601276  0.573724  0.601276
#
#                  param
# 2  C: 1\ngamma: 0.0001

# %%
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.tight_layout()
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=30, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.1, right=0.98, bottom=0.25, top=0.95)
plt.savefig('./Metrics/figure/AMES_svm_basic.jpg')

# %%
#Norm
df = pd.read_csv('./Metrics/AMES_svm_minmax.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'C: ' + df['0']
df['1'] = 'gamma: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=30, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.1, right=0.98, bottom=0.25, top=0.95)

plt.savefig('./Metrics/figure/AMES_svm_minmax.jpg')

# %%
df = pd.read_csv('./Metrics/AMES_svm_over.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'C: ' + df['0']
df['1'] = 'gamma: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=30, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.1, right=0.98, bottom=0.25, top=0.95)

plt.savefig('./Metrics/figure/AMES_svm_over.jpg')

# %% [markdown]
# # hERG

# %% [markdown]
# ## lr

# %%
#Basic
df = pd.read_csv('./Metrics/hERG_lr_basic.csv',index_col=0)
df.sample()
# Out:
#    0         1         2         3        4         5
# 0  1  0.679087  0.669802  0.657297  0.65923  0.657297

# %%
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=3)
plt.savefig('./Metrics/figure/hERG_lr_basic.jpg')

# %%
#Normalize
df = pd.read_csv('./Metrics/hERG_lr_minmax.csv',index_col=0)
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=3)
plt.savefig('./Metrics/figure/hERG_lr_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/hERG_lr_over.csv',index_col=0)
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=2)
plt.savefig('./Metrics/figure/hERG_lr_over.jpg')

# %% [markdown]
# ## lgbm

# %%
#Basic
df = pd.read_csv('./Metrics/hERG_lgbm_basic.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
df.sample()
# Out:
#            0          1         2       3         4         5         6  \
# 24  lr: 0.01  tree: 500  0.798865  0.7976  0.784702  0.788988  0.784702
#
#                   param
# 24  lr: 0.01\ntree: 500

# %%
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


plt.savefig('./Metrics/figure/hERG_lgbm_basic.jpg')

# %%
#Norm
df = pd.read_csv('./Metrics/hERG_lgbm_minmax.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)

x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


plt.savefig('./Metrics/figure/hERG_lgbm_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/hERG_lgbm_over.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)

x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


plt.savefig('./Metrics/figure/hERG_lgbm_over.jpg')

# %% [markdown]
# ## RF

# %%
#Basic
df = pd.read_csv('./Metrics/hERG_rf_basic.csv',index_col=0)
df.sample()
# Out:
#      0         1         2        3        4         5
# 0  100  0.845983  0.843222  0.83664  0.84178  0.839698

# %%
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=3)
plt.savefig('./Metrics/figure/hERG_rf_basic.jpg')

# %%
#Normalize
df = pd.read_csv('./Metrics/hERG_rf_minmax.csv',index_col=0)

x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=3)
plt.savefig('./Metrics/figure/hERG_rf_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/hERG_rf_over.csv',index_col=0)

x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.savefig('./Metrics/figure/hERG_rf_over.jpg')

# %% [markdown]
# ## kNN

# %%
#Basic
df = pd.read_csv('./Metrics/hERG_knn_basic.csv',index_col=0)
df.sample()
# Out:
#    0         1         2         3         4         5
# 0  3  0.706137  0.697318  0.692858  0.694462  0.692858

# %%
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=3)
plt.savefig('./Metrics/figure/hERG_knn_basic.jpg')

# %%
#Norm
df = pd.read_csv('./Metrics/hERG_knn_minmax.csv',index_col=0)
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=3)
plt.savefig('./Metrics/figure/hERG_knn_minmax.jpg')

# %%
#over
df = pd.read_csv('./Metrics/hERG_knn_over.csv',index_col=0)
df['0'] = df['0'].astype(int).astype(str)
x_values = df['0']
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=3)
plt.savefig('./Metrics/figure/hERG_knn_over.jpg')

# %% [markdown]
# ## SVM

# %%
#Basic
df = pd.read_csv('./Metrics/hERG_svm_basic.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'C: ' + df['0']
df['1'] = 'gamma: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
df.sample()
# Out:
#         0             1        2         3         4         5         6  \
# 7  C: 100  gamma: 0.001  0.79649  0.791092  0.788824  0.789834  0.788824
#
#                   param
# 7  C: 100\ngamma: 0.001

# %%
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.tight_layout()
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=30, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.1, right=0.98, bottom=0.25, top=0.95)
plt.savefig('./Metrics/figure/hERG_svm_basic.jpg')

# %%
# #Norm
# df = pd.read_csv('./Metrics/hERG_svm_minmax.csv',index_col=0)
# df['0'] = df['0'].astype(str)
# df['1'] = df['1'].astype(str)
# df['0'] = 'C: ' + df['0']
# df['1'] = 'gamma: ' + df['1']

# df['param'] = df[['0','1']].apply('\n'.join, axis=1)
# x_values = df['param']

# y_value1 = df['2']
# y_value2 = df['3']
# y_value3 = df['4']
# y_value4 = df['5']
# y_value5 = df['6']

# # plt.ylim([0.55, 0.65])
# # plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
# plt.xticks(rotation=30, ha='right')
# plt.plot(x_values, y_value1, marker='o', label='Accuracy')
# plt.plot(x_values, y_value2, marker='o', label='Precision')
# plt.plot(x_values, y_value3, marker='s', label='Recall')
# plt.plot(x_values, y_value4, marker='o', label='F1')
# plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
# plt.legend(loc=4)
# plt.subplots_adjust(left=0.1, right=0.98, bottom=0.25, top=0.95)

# plt.savefig('./Metrics/figure/hERG_svm_minmax.jpg')

# %%
# #over
# df = pd.read_csv('./Metrics/hERG_svm_over.csv',index_col=0)
# df['0'] = df['0'].astype(str)
# df['1'] = df['1'].astype(str)
# df['0'] = 'C: ' + df['0']
# df['1'] = 'gamma: ' + df['1']

# df['param'] = df[['0','1']].apply('\n'.join, axis=1)
# x_values = df['param']

# y_value1 = df['2']
# y_value2 = df['3']
# y_value3 = df['4']
# y_value4 = df['5']
# y_value5 = df['6']

# # plt.ylim([0.55, 0.65])
# # plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
# plt.xticks(rotation=30, ha='right')
# plt.plot(x_values, y_value1, marker='o', label='Accuracy')
# plt.plot(x_values, y_value2, marker='o', label='Precision')
# plt.plot(x_values, y_value3, marker='s', label='Recall')
# plt.plot(x_values, y_value4, marker='o', label='F1')
# plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
# plt.legend(loc=4)
# plt.subplots_adjust(left=0.1, right=0.98, bottom=0.25, top=0.95)

# plt.savefig('./Metrics/figure/hERG_svm_over.jpg')

# %% [markdown]
# # EPA

# %% [markdown]
# ## lr

# %%
#Basic
df = pd.read_csv('./Metrics/EPA_lr_basic.csv',index_col=0)
df.sample()
# Out:
#     0         1         2         3       4         5
# 4  16  0.565479  0.535528  0.439979  0.4629  0.439979

# %%
x_values = np.log(df['0'])
y_value1 = df['1']
y_value2 = df['2']
y_value3 = df['3']
y_value4 = df['4']
y_value5 = df['5']
# plt.ylim([0.55, 0.65])
plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=3)
plt.savefig('./Metrics/figure/EPA_lr_basic.jpg')

# %%
# #Normalize
# df = pd.read_csv('./Metrics/EPA_lr_minmax.csv',index_col=0)
# x_values = np.log(df['0'])
# y_value1 = df['1']
# y_value2 = df['2']
# y_value3 = df['3']
# y_value4 = df['4']
# y_value5 = df['5']
# # plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

# plt.plot(x_values, y_value1, marker='o', label='Accuracy')
# plt.plot(x_values, y_value2, marker='o', label='Precision')
# plt.plot(x_values, y_value3, marker='s', label='Recall')
# plt.plot(x_values, y_value4, marker='o', label='F1')
# plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
# plt.legend(loc=1)
# plt.savefig('./Metrics/figure/EPA_lr_minmax.jpg')

# %%
# #over
# df = pd.read_csv('./Metrics/EPA_lr_over.csv',index_col=0)
# x_values = np.log(df['0'])
# y_value1 = df['1']
# y_value2 = df['2']
# y_value3 = df['3']
# y_value4 = df['4']
# y_value5 = df['5']
# # plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

# plt.plot(x_values, y_value1, marker='o', label='Accuracy')
# plt.plot(x_values, y_value2, marker='o', label='Precision')
# plt.plot(x_values, y_value3, marker='s', label='Recall')
# plt.plot(x_values, y_value4, marker='o', label='F1')
# plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
# plt.legend(loc=1)
# plt.savefig('./Metrics/figure/EPA_lr_over.jpg')

# %% [markdown]
# ## LGBM

# %%
#Basic
df = pd.read_csv('./Metrics/EPA_lgbm_basic.csv',index_col=0)
df['0'] = df['0'].astype(str)
df['1'] = df['1'].astype(str)
df['0'] = 'lr: ' + df['0']
df['1'] = 'tree: ' + df['1']

df['param'] = df[['0','1']].apply('\n'.join, axis=1)
df.sample()
# Out:
#            0          1         2         3         4         5         6  \
# 10  lr: 0.05  tree: 100  0.628831  0.644835  0.529015  0.561694  0.529015
#
#                   param
# 10  lr: 0.05\ntree: 100

# %%
x_values = df['param']

y_value1 = df['2']
y_value2 = df['3']
y_value3 = df['4']
y_value4 = df['5']
y_value5 = df['6']

plt.figure(figsize=(15,5))
# plt.ylim([0.55, 0.65])
# plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
plt.xticks(rotation=60, ha='right')
plt.plot(x_values, y_value1, marker='o', label='Accuracy')
plt.plot(x_values, y_value2, marker='o', label='Precision')
plt.plot(x_values, y_value3, marker='s', label='Recall')
plt.plot(x_values, y_value4, marker='o', label='F1')
plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
plt.legend(loc=4)
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


plt.savefig('./Metrics/figure/EPA_lgbm_basic.jpg')

# %%
# #Norm
# df = pd.read_csv('./Metrics/EPA_lgbm_minmax.csv',index_col=0)
# df['0'] = df['0'].astype(str)
# df['1'] = df['1'].astype(str)
# df['0'] = 'lr: ' + df['0']
# df['1'] = 'tree: ' + df['1']

# df['param'] = df[['0','1']].apply('\n'.join, axis=1)

# x_values = df['param']

# y_value1 = df['2']
# y_value2 = df['3']
# y_value3 = df['4']
# y_value4 = df['5']
# y_value5 = df['6']

# plt.figure(figsize=(15,5))
# # plt.ylim([0.55, 0.65])
# # plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
# plt.xticks(rotation=60, ha='right')
# plt.plot(x_values, y_value1, marker='o', label='Accuracy')
# plt.plot(x_values, y_value2, marker='o', label='Precision')
# plt.plot(x_values, y_value3, marker='s', label='Recall')
# plt.plot(x_values, y_value4, marker='o', label='F1')
# plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
# plt.legend(loc=4)
# plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


# plt.savefig('./Metrics/figure/EPA_lgbm_minmax.jpg')

# %%
# #over
# df = pd.read_csv('./Metrics/EPA_lgbm_over.csv',index_col=0)
# df['0'] = df['0'].astype(str)
# df['1'] = df['1'].astype(str)
# df['0'] = 'lr: ' + df['0']
# df['1'] = 'tree: ' + df['1']

# df['param'] = df[['0','1']].apply('\n'.join, axis=1)

# x_values = df['param']

# y_value1 = df['2']
# y_value2 = df['3']
# y_value3 = df['4']
# y_value4 = df['5']
# y_value5 = df['6']

# plt.figure(figsize=(15,5))
# # plt.ylim([0.55, 0.65])
# # plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])
# plt.xticks(rotation=60, ha='right')
# plt.plot(x_values, y_value1, marker='o', label='Accuracy')
# plt.plot(x_values, y_value2, marker='o', label='Precision')
# plt.plot(x_values, y_value3, marker='s', label='Recall')
# plt.plot(x_values, y_value4, marker='o', label='F1')
# plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
# plt.legend(loc=4)
# plt.subplots_adjust(left=0.05, right=0.95, bottom=0.2, top=0.95)


# plt.savefig('./Metrics/figure/EPA_lgbm_over.jpg')

# %% [markdown]
# ## RF

# %%
# #Basic
# df = pd.read_csv('./Metrics/EPA_rf_basic.csv',index_col=0)
# df.sample()

# %%
# x_values = df['0']
# y_value1 = df['1']
# y_value2 = df['2']
# y_value3 = df['3']
# y_value4 = df['4']
# y_value5 = df['5']
# # plt.ylim([0.55, 0.65])
# # plt.xticks(np.arange(0, 5.6, 0.7), labels=['1','2','4','8','16','32','64','128'])

# plt.plot(x_values, y_value1, marker='o', label='Accuracy')
# plt.plot(x_values, y_value2, marker='o', label='Precision')
# plt.plot(x_values, y_value3, marker='s', label='Recall')
# plt.plot(x_values, y_value4, marker='o', label='F1')
# plt.plot(x_values, y_value5, marker='o', label='Balanced Accuracy')
# plt.legend(loc=4)
# plt.savefig('./Metrics/figure/EPA_rf_basic.jpg')
